# %% [markdown]
# # Backpropagation and Gradient Descent with Keras
#
# This notebook explores how backpropagation and different variants of
# gradient descent work in practice using Keras.

# %% [markdown]
# ## Sections
# 1. Simple Neural Network Setup
# 2. Backpropagation via Training
# 3. Batch Gradient Descent
# 4. Stochastic Gradient Descent
# 5. Mini-batch Gradient Descent

# %%
import numpy as np
import tensorflow as tf
import keras 
from keras import layers
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
X = np.array([[1], [2], [3], [4]])
y = np.array([2, 4, 6, 8])

# %%
model = Sequential([
    Dense(1, input_shape=(1,))
])

model.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='mse'
)
# Out:
# c:\Users\SOHAM\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# This model performs a forward pass and computes loss using Mean Squared Error.

# %%
history = model.fit(
    X,
    y,
    epochs=25,
    verbose=1
)
# Out:
# Epoch 1/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 23.7309
# Epoch 2/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 23.3863
# Epoch 3/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 23.0451
# Epoch 4/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 22.7073
# Epoch 5/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 22.3729
# Epoch 6/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 22.0419
# Epoch 7/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 21.7144
# Epoch 8/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 21.3903
# Epoch 9/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 21.0697
# Epoch 10/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 20.7525
# Epoch 11/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 20.4388
# Epoch 12/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 20.1285
# Epoch 13/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 19.8216
# Epoch 14/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 19.5182
# Epoch 15/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 19.2182
# Epoch 16/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 18.9216
# Epoch 17/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 18.6285
# Epoch 18/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 18.3387
# Epoch 19/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 18.0523
# Epoch 20/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 17.7694
# Epoch 21/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 17.4897
# Epoch 22/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 17.2135
# Epoch 23/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 16.9405
# Epoch 24/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 16.6709
# Epoch 25/25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 16.4046

# %%
model.get_weights()
# Out:
# [array([[0.39028338]], dtype=float32), array([0.432269], dtype=float32)]

# %% [markdown]
# During training, Keras automatically performs backpropagation to compute gradients and update weights.

# %%
#Batch Gradient Descent
model_batch = Sequential([Dense(1, input_shape=(1,))])
model_batch.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='mse'
)

model_batch.fit(X, y, epochs=20, batch_size=len(X), verbose=0)
# Out:
# c:\Users\SOHAM\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Stochastic Gradient Descent
model_sgd = Sequential([Dense(1, input_shape=(1,))])
model_sgd.compile(
    optimizer=Adam(learning_rate=0.01),
    loss='mse'
)

model_sgd.fit(X, y, epochs=20, batch_size=1, verbose=0)
# Out:
# c:\Users\SOHAM\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Batch size controls how frequently weights are updated.
