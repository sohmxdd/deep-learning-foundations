# %% [markdown]
# # Backpropagation and Gradient Descent
#
# This notebook explores how gradients are computed using backpropagation
# and how different variants of gradient descent use these gradients
# to update model parameters.

# %% [markdown]
# # Backpropagation and Gradient Descent
#
# This notebook explores how gradients are computed using backpropagation
# and how different variants of gradient descent use these gradients
# to update model parameters.
